# %%
# Libraries 

import pandas as pd
import numpy as np
import csv
import os
import time
import pycountry as pcty
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import re
import torch
import string
import nltk

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# ***** import vader_dataset instead of re-run the code ***** 
filename = 'vader_dataset.csv' 

if os.path.exists(filename):
    vader_dataset = pd.read_csv(filename)

# %%
vader_dataset.sample(5)
# Out:
#           id  vader_neg  vader_neu  vader_pos  vader_compound  \
# 60428  60943      0.089      0.636      0.275          0.9620
# 19069  19092      0.000      0.597      0.403          0.9260
# 21391  21416      0.000      0.548      0.452          0.9829
# 33604  33635      0.000      0.464      0.536          0.9911
# 3321    3324      0.000      0.717      0.283          0.9776
#
#                              hotelname  comment_count  rating  rating_word  \
# 60428     Pullman Kuala Lumpur Bangsar           1716     4.0            1
# 19069         Grand Hyatt Kuala Lumpur           5462     4.5            2
# 21391          Shangri-La Kuala Lumpur           8548     4.5            2
# 33604  Mandarin Oriental, Kuala Lumpur           7269     4.5            2
# 3321               Hilton Kuala Lumpur           6421     4.5            2
#
#        location_rating  ...  contributes  helpfulvotes_guest  \
# 60428              3.5  ...         98.0                76.0
# 19069              5.0  ...         18.0                16.0
# 21391              4.5  ...        623.0               204.0
# 33604              5.0  ...         10.0                 5.0
# 3321               4.5  ...         23.0                 4.0
#
#        guest_rating_bubble                                             review  \
# 60428                  3.0  luxury reasonable price stayed first week sept...
# 19069                  5.0  great hotel stayed girlfriend arrived late joh...
# 21391                  5.0  best buffet breakfast stayed premier selection...
# 33604                  5.0  special experience husband recently stayed hot...
# 3321                   5.0  always home away home th stay hilton last four...
#
#             dateofStay    guestCountry hotelname_encode dateofStay_encode  \
# 60428   September 2014           India               16             92014
# 19069   September 2013   Not Mentioned                7             92013
# 21391         May 2017       Australia               20             52017
# 33604       March 2017  United Kingdom               14             32017
# 3321         July 2019       Indonesia                9             72019
#
#       guestCountry_encode  polarity_vader
# 60428                  61        positive
# 19069                 105        positive
# 21391                   9        positive
# 33604                 142        positive
# 3321                   62        positive
#
# [5 rows x 23 columns]

# %%
# Select only the relevant columns
data = vader_dataset[['hotelname', 'review', 'polarity_vader']]

# %%
data.sample(10)
# Out:
#                                          hotelname  \
# 2418                           Hilton Kuala Lumpur
# 9539                             8 Kia Peng Suites
# 58950                   Royale Chulan Kuala Lumpur
# 12486                     Le Meridien Kuala Lumpur
# 21858                      Shangri-La Kuala Lumpur
# 18420                     Grand Hyatt Kuala Lumpur
# 3011                           Hilton Kuala Lumpur
# 18620                     Grand Hyatt Kuala Lumpur
# 42347                      The Westin Kuala Lumpur
# 29869  InterContinental Kuala Lumpur, an IHG Hotel
#
#                                                   review polarity_vader
# 2418   perfect hotel kuala lumpur excellent service e...       positive
# 9539   best experience kl long term say family person...       positive
# 58950  superb hotel fault stayed royal chulan day chr...       positive
# 12486  comfy stay hubby stayed night sponsored actual...       positive
# 21858  year vacation warm welcome staff excellent ser...       positive
# 18420  fabulous hotel superb location recently stayed...       positive
# 3011   beautiful room great breakfast hotel accessibl...       positive
# 18620  hyatt kuala lumpur top hotel room amazing view...       positive
# 42347  avoid possible stayed westin kl oct checked fr...       negative
# 29869  good location friendly staff first staff kl go...       positive

# %%
vader_dataset[vader_dataset['polarity_vader'] == 'negative']
# Out:
#           id  vader_neg  vader_neu  vader_pos  vader_compound  \
# 40        41      0.230      0.672      0.098         -0.9166
# 203      204      0.193      0.635      0.173         -0.2263
# 265      266      0.079      0.849      0.072         -0.1513
# 598      599      0.169      0.700      0.131         -0.3612
# 751      752      0.144      0.766      0.090         -0.3637
# ...      ...        ...        ...        ...             ...
# 63535  64052      0.189      0.693      0.118         -0.4939
# 63543  64060      0.221      0.611      0.168         -0.7648
# 63546  64063      0.430      0.506      0.064         -0.9423
# 63547  64064      0.102      0.855      0.043         -0.4215
# 63548  64065      0.449      0.551      0.000         -0.9788
#
#                                     hotelname  comment_count  rating  \
# 40                            EQ Kuala Lumpur            575     5.0
# 203                           EQ Kuala Lumpur            575     5.0
# 265                           EQ Kuala Lumpur            575     5.0
# 598    Lanson Place Bukit Ceylon Kuala Lumpur           1064     5.0
# 751    Lanson Place Bukit Ceylon Kuala Lumpur           1064     5.0
# ...                                       ...            ...     ...
# 63535             E&O Residences Kuala Lumpur            946     4.0
# 63543             E&O Residences Kuala Lumpur            946     4.0
# 63546             E&O Residences Kuala Lumpur            946     4.0
# 63547             E&O Residences Kuala Lumpur            946     4.0
# 63548             E&O Residences Kuala Lumpur            946     4.0
#
#        rating_word  location_rating  ...  contributes  helpfulvotes_guest  \
# 40               2              5.0  ...          1.0                 0.0
# 203              2              5.0  ...         64.0                64.0
# 265              2              5.0  ...      10110.0               240.0
# 598              2              5.0  ...          1.0                 3.0
# 751              2              5.0  ...         87.0                85.0
# ...            ...              ...  ...          ...                 ...
# 63535            1              4.5  ...          1.0                 0.0
# 63543            1              4.5  ...        300.0               148.0
# 63546            1              4.5  ...          0.0                 0.0
# 63547            1              4.5  ...          0.0                 0.0
# 63548            1              4.5  ...          3.0                 0.0
#
#        guest_rating_bubble                                             review  \
# 40                     5.0  unforgetable delightful stay eq hotel booked n...
# 203                    1.0  insensitive receptionist seemingly oblivious f...
# 265                    5.0  perfection equatorial one older name kuala lum...
# 598                    2.0  rude unprofessional hospitality never experien...
# 751                    1.0  high rise building noisy initially gave star s...
# ...                    ...                                                ...
# 63535                  3.0  location great difficult evaluate hotel pick h...
# 63543                  2.0  worn place avoid dont understand excellent rat...
# 63546                  1.0  bad experience hotel side pool side nice cozy ...
# 63547                  1.0  الفندق غير جيد الفطور اقل من عادي طابور عند ال...
# 63548                  1.0  worst ever worst hotel resident ever life sinc...
#
#             dateofStay    guestCountry hotelname_encode dateofStay_encode  \
# 40       November 2022   Not Mentioned                5            112022
# 203      December 2021        Malaysia                5            122021
# 265      February 2021        Malaysia                5             22021
# 598           May 2022           Japan               12             52022
# 751       January 2020  United Kingdom               12             12020
# ...                ...             ...              ...               ...
# 63535   September 2017   Not Mentioned                4             92017
# 63543      August 2017         Belgium                4             82017
# 63546      August 2017   Not Mentioned                4             82017
# 63547      August 2017   Not Mentioned                4             82017
# 63548        July 2017   Not Mentioned                4             72017
#
#       guestCountry_encode  polarity_vader
# 40                    105        negative
# 203                    84        negative
# 265                    84        negative
# 598                    68        negative
# 751                   142        negative
# ...                   ...             ...
# 63535                 105        negative
# 63543                  17        negative
# 63546                 105        negative
# 63547                 105        negative
# 63548                 105        negative
#
# [2360 rows x 23 columns]

# %%
# Create a list of unique hotel names
hotel_names = data['hotelname'].unique()

# %%
hotel_names
# Out:
# array(['EQ Kuala Lumpur', 'Lanson Place Bukit Ceylon Kuala Lumpur',
#        'Banyan Tree Kuala Lumpur', 'Hilton Kuala Lumpur',
#        'Four Seasons Hotel Kuala Lumpur', 'The RuMa Hotel and Residences',
#        '8 Kia Peng Suites', 'Le Meridien Kuala Lumpur',
#        'Sofitel Kuala Lumpur Damansara', 'Grand Hyatt Kuala Lumpur',
#        'W Hotels Kuala Lumpur', 'Shangri-La Kuala Lumpur',
#        'Pavilion Hotel Kuala Lumpur Managed by Banyan Tree Kuala Lumpur',
#        'InterContinental Kuala Lumpur, an IHG Hotel',
#        'Mandarin Oriental, Kuala Lumpur', 'The St. Regis Kuala Lumpur',
#        'Ascott Kuala Lumpur', 'Alila Bangsar Kuala Lumpur',
#        'The Ritz-Carlton, Kuala Lumpur', 'The Westin Kuala Lumpur',
#        'JW Marriott Hotel Kuala Lumpur',
#        'The Majestic Hotel Kuala Lumpur', 'The Face Suites',
#        'Pullman Kuala Lumpur City Centre Hotel & Residences',
#        'The Gardens-A St Giles Signature Hotel & Residence',
#        'Renaissance Kuala Lumpur Hotel & Convention Centre',
#        'Royale Chulan Kuala Lumpur', 'Pullman Kuala Lumpur Bangsar',
#        'Grand Millennium Hotel Kuala Lumpur',
#        'E&O Residences Kuala Lumpur'], dtype=object)

# %% [markdown]
# ### IDF Value for Top 5 Feature Words in negative reviews for each Hotel

# %%
# Get only the negative reviews
negative_reviews = vader_dataset[vader_dataset['polarity_vader'] == 'negative']

# Group the negative reviews by hotelname
grouped_reviews = negative_reviews.groupby('hotelname')

# Create a TfidfVectorizer object with English stopwords
vectorizer = TfidfVectorizer(stop_words='english')

# Loop through each hotel and get the top 10 feature words
for hotel, group in grouped_reviews:
    # Fit the vectorizer on the hotel's negative reviews
    vectorizer.fit(group['review'])
    # Get the feature names and their corresponding tf-idf scores
    feature_names = vectorizer.get_feature_names_out() #get_feature_names()
    tfidf_scores = vectorizer.transform(group['review'])
    # Convert the tf-idf scores to a pandas DataFrame
    tfidf_df = pd.DataFrame(tfidf_scores.T.todense(), index=feature_names, columns=group['id'])
    # Get the top 10 feature words for the hotel
    top_features = tfidf_df.sum(axis=1).nlargest(5)
    print(f"Hotel: {hotel}")
    print(top_features)
    print('\n')
# Out:
# Hotel: 8 Kia Peng Suites
# refund    0.536141
# money     0.402106
# pm        0.394535
# small     0.338813
# quite     0.313986
# dtype: float64
#
#
# Hotel: Alila Bangsar Kuala Lumpur
# room       2.439821
# hotel      1.830454
# check      1.386901
# pm         1.307858
# service    1.147229
# dtype: float64
#
#
# Hotel: Ascott Kuala Lumpur
# room       3.903782
# service    2.911682
# hotel      2.487037
# time       2.210659
# bad        2.151975
# dtype: float64
#
#
# Hotel: Banyan Tree Kuala Lumpur
# hotel     1.509718
# room      1.488126
# tea       1.179182
# tree      1.108069
# banyan    1.106643
# dtype: float64
#
#
# Hotel: E&O Residences Kuala Lumpur
# room         3.425365
# bad          2.249203
# hotel        1.936291
# apartment    1.784479
# towel        1.512590
# dtype: float64
#
#
# Hotel: EQ Kuala Lumpur
# hotel     0.556802
# blue      0.379825
# booked    0.379825
# sky       0.379825
# kl        0.317279
# dtype: float64
#
#
# Hotel: Four Seasons Hotel Kuala Lumpur
# room       2.178194
# hotel      1.925075
# season     1.194037
# day        1.177019
# service    1.146851
# dtype: float64
#
#
# Hotel: Grand Hyatt Kuala Lumpur
# room       7.974096
# hotel      6.013459
# service    4.355773
# staff      4.097046
# check      3.688908
# dtype: float64
#
#
# Hotel: Grand Millennium Hotel Kuala Lumpur
# hotel      12.883595
# room       12.621792
# service     7.281996
# check       7.086443
# staff       7.045932
# dtype: float64
#
#
# Hotel: Hilton Kuala Lumpur
# room       12.414041
# hotel       9.024238
# service     6.797027
# hilton      6.656411
# time        5.679952
# dtype: float64
#
#
# Hotel: InterContinental Kuala Lumpur, an IHG Hotel
# hotel      7.937449
# room       6.954101
# service    4.432350
# staff      3.596019
# star       3.217483
# dtype: float64
#
#
# Hotel: JW Marriott Hotel Kuala Lumpur
# room        8.201316
# hotel       7.368970
# service     4.167335
# staff       4.065101
# marriott    3.938856
# dtype: float64
#
#
# Hotel: Lanson Place Bukit Ceylon Kuala Lumpur
# room     1.200165
# place    0.831321
# stay     0.675107
# bad      0.545237
# smell    0.531856
# dtype: float64
#
#
# Hotel: Le Meridien Kuala Lumpur
# room       8.001218
# hotel      7.816392
# staff      4.034108
# service    3.821196
# stay       3.820164
# dtype: float64
#
#
# Hotel: Mandarin Oriental, Kuala Lumpur
# room        10.503287
# hotel       10.130512
# service      7.448591
# stay         5.555457
# mandarin     5.151780
# dtype: float64
#
#
# Hotel: Pavilion Hotel Kuala Lumpur Managed by Banyan Tree Kuala Lumpur
# hotel         3.198547
# room          3.108953
# service       1.473097
# stay          1.249968
# experience    1.206467
# dtype: float64
#
#
# Hotel: Pullman Kuala Lumpur Bangsar
# hotel      6.891103
# room       6.073576
# service    3.044443
# staff      2.752828
# stay       2.622233
# dtype: float64
#
#
# Hotel: Pullman Kuala Lumpur City Centre Hotel & Residences
# room         2.057851
# hotel        1.587632
# breakfast    1.520711
# staff        1.233792
# night        1.084014
# dtype: float64
#
#
# Hotel: Renaissance Kuala Lumpur Hotel & Convention Centre
# room       20.149402
# hotel      17.734424
# service     9.611652
# wing        9.009367
# staff       7.654424
# dtype: float64
#
#
# Hotel: Royale Chulan Kuala Lumpur
# room       8.809845
# hotel      8.178071
# service    4.374090
# staff      3.859155
# stay       3.534273
# dtype: float64
#
#
# Hotel: Shangri-La Kuala Lumpur
# room       11.358732
# hotel      10.079674
# service     6.153045
# stay        5.539690
# staff       5.019629
# dtype: float64
#
#
# Hotel: Sofitel Kuala Lumpur Damansara
# room       4.494288
# hotel      3.338277
# service    2.592226
# staff      2.003559
# sofitel    1.998259
# dtype: float64
#
#
# Hotel: The Face Suites
# pool       2.611519
# room       2.430312
# check      2.124451
# service    1.964068
# hotel      1.766429
# dtype: float64
#
#
# Hotel: The Gardens-A St Giles Signature Hotel & Residence
# hotel      8.898623
# room       7.226809
# service    4.115467
# mall       3.725229
# bad        3.417620
# dtype: float64
#
#
# Hotel: The Majestic Hotel Kuala Lumpur
# hotel      6.059665
# room       5.872724
# tea        4.276624
# service    4.120850
# food       3.284089
# dtype: float64
#
#
# Hotel: The Ritz-Carlton, Kuala Lumpur
# hotel      4.253467
# room       3.915028
# service    3.240597
# ritz       3.021881
# time       2.042585
# dtype: float64
#
#
# Hotel: The RuMa Hotel and Residences
# hotel      2.322552
# room       2.068241
# time       1.968557
# staying    1.840994
# food       1.708639
# dtype: float64
#
#
# Hotel: The St. Regis Kuala Lumpur
# hotel      1.375434
# service    1.265018
# room       1.212819
# st         0.995695
# regis      0.985699
# dtype: float64
#
#
# Hotel: The Westin Kuala Lumpur
# room      12.563294
# hotel      9.564028
# westin     6.003358
# staff      5.321973
# time       5.271705
# dtype: float64
#
#
# Hotel: W Hotels Kuala Lumpur
# customer    0.859144
# hotel       0.688338
# service     0.676369
# room        0.631236
# worst       0.511239
# dtype: float64

# %% [markdown]
# ### IDF Value for Top 10 Feature Words in negative reviews

# %%
vectorizer.fit(negative_reviews['review'])
# Get the feature names and their corresponding tf-idf scores
feature_names = vectorizer.get_feature_names_out()
tfidf_scores = vectorizer.transform(negative_reviews['review'])

# Convert the tf-idf scores to a pandas DataFrame
tfidf_df = pd.DataFrame(tfidf_scores.T.todense(), index=feature_names, columns=negative_reviews['id'])

# Get the top 10 feature words for the hotel
top_features = tfidf_df.sum(axis=1).nlargest(10)

print(top_features)
print('\n')
# Out:
# room         143.729324
# hotel        130.292333
# service       79.574239
# staff         65.854857
# stay          59.798086
# time          57.429851
# check         52.704619
# bad           52.137996
# breakfast     51.232002
# star          50.667537
# dtype: float64
